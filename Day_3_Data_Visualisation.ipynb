# %% [markdown]
# ASSIGNMENT-1</br>
# NAME :- YADAVI JAYARAM SHETTY </br>
# EMAIL:- yadavishetty3804@gmail.com </br> Date : 11/06/2021

# %%
import numpy as np
import matplotlib as mpl
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from numpy.random import randn,randint,uniform,sample
# %matplotlib inline

# %%
fmri= sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(y='signal',x='timepoint',kind='line',hue='event',size='region',data=fmri)

# %%
sns.relplot(y='signal',x='timepoint',kind='line',hue='subject',size='region',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',hue='subject',style='event',size='region',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',hue='event',style='subject',size='region',data=fmri)

# %%
sns.lineplot(y='signal',x='timepoint',data=fmri)

# %%
sns.relplot(x='timepoint',y='signal',hue='subject',style='event',size='region',data=fmri,kind='line')

# %%
sns.relplot(x='timepoint',y='signal',hue='event',style='subject',size='region',data=fmri,kind='line')

# %%
fmri.dtypes
# Out:
# subject       object
# timepoint      int64
# event         object
# region        object
# signal       float64
# dtype: object

# %%
fmri.describe()
# Out:
#          timepoint       signal
# count  1064.000000  1064.000000
# mean      9.000000     0.003540
# std       5.479801     0.093930
# min       0.000000    -0.255486
# 25%       4.000000    -0.046070
# 50%       9.000000    -0.013653
# 75%      14.000000     0.024293
# max      18.000000     0.564985

# %%
sns.boxplot(x='timepoint',y='signal',hue='region', data=fmri)

# %%
sns.boxplot(x='timepoint',y='signal',hue='event',data=fmri)
